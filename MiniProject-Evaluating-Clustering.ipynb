# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulmajeed-A/Tuwaiq-MiniProject-Evaluating-Clustering/blob/main/MiniProject-Evaluating-Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports & Data

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_digits
from sklearn.preprocessing import StandardScaler

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans

# %% [markdown]
# # 1. Preprocess data
# * Handle missing values (if any)
# * Apply scaling (Standardization is required)

# %% [markdown]
# # 2. Apply Clustering (Before PCA)
# * Apply K-Means on the original data
# * Record results

# %% [markdown]
# # 3. Apply PCA
# * Reduce the data to 2 components

# %% [markdown]
# # 4. Apply Clustering (After PCA)
# * Apply K-Means on the transformed data

# %% [markdown]
# # 5. Visualization
# * Visualize clusters (2D using PCA components)
# * Compare before vs after PCA

# %% [markdown]
# # Analysis (Very Important!)
#
# How did PCA affect clustering results?
# * Answear...
#
# Did visualization become clearer?
# * Answear...
#
# Did you lose important information?
# * Answear...
#
# Which approach is better and why?
# * Answear...

# %% [markdown]
# # Key Insights:
#
# * Insight 1
# * Insight 2
# * Ins......
